# %%
import pandas as pd
from IPython.display import display

# %% [markdown]
# # Configuration

# %%
# =========================
# Config
# =========================
LLM_CSV_PATH = "sample/sample_llm_results.csv"     # LLM results
GT_CSV_PATH  = "sample/sample_ground_truth.csv"    # ground truth

# %%
# =========================
# Config Continued, (edit these IF NEEDED).
# =========================

# Column in BOTH CSVs that contains the paper identifier (first column by position).
PAPER_ID_COL = "paper_id"

# Predefined criteria and paper IDs.
CRITERIA = [
    "criteria a.1", "criteria a.2", "criteria a.3", "criteria a.4", "criteria a.5",
    "criteria b.1", "criteria b.2", "criteria b.3", "criteria b.4", "criteria b.5",
    "criteria c",
    "criteria d.1", "criteria d.2", "criteria d.3",
    "criteria e.1", "criteria e.2", "criteria e.3", "criteria e.4",
]

PAPER_IDS = [
    "Allcott, H (2011) (1)",
    "Ayres, Raseman, Shih, 2012",
    "Bager, S; Mundaca, L (2017)",
    "Carroll, J; Lyons, S; Denny, E (2014)",
    "Houde, S; Todd, A; Sudarshan, A; Flora, JA; Armel, KC (2013)",
    "Marangoni and Tavoni, 2021",
    "Matsukawa, I. (2018)",
]

'''
This will use the predefined PAPER_IDS and CRITERIA instead of taking values from any of the dataset. 
Hence, naming isn't important here, but ordering of the paper and criteria will be important. Ordering has to be the same between both dataset.
'''

# Presentation
DISPLAY_SEPARATOR = " / "  # string between LLM and GT values in a cell.

# %% [markdown]
# # Result Comparison

# %%
# =========================
# Imports & helpers
# =========================
df_llm = pd.read_csv(LLM_CSV_PATH)
df_gt = pd.read_csv(GT_CSV_PATH)

def _canon_label(x: object) -> str:
    """Lowercase; map 'probably yes/no' to 'yes/no'; empty for NaN."""
    if pd.isna(x):
        return ""
    s = str(x).strip().lower()
    if s == "probably yes":
        s = "yes"
    elif s == "probably no":
        s = "no"
    return s

def _clean_col(s: str) -> str:
    """Simple normalization for column names (used in string mode)."""
    return " ".join(str(s).strip().lower().split())

def load_by_position(dataframe: pd.DataFrame, path: str, paper_ids: list[str], criteria: list[str], paper_id_col: str) -> pd.DataFrame:
    """
    Read CSV assuming:
    - First column (by position) is the paper id, and rows appear in the same order as PAPER_IDS
    - Next len(criteria) columns (by position) correspond to CRITERIA in that exact order
    Any extra columns after criteria are ignored. Column *names* in the file don't matter.
    """
    df = dataframe
    # Basic shape check
    need_cols = 1 + len(criteria)
    if df.shape[1] < need_cols:
        raise ValueError(f"{path}: expected at least {need_cols} columns (id + {len(criteria)} criteria), got {df.shape[1]}.")

    # Slice columns by position
    df = df.iloc[:, :need_cols]

    # Rename columns to canonical names (first col -> PAPER_ID_COL, rest -> CRITERIA)
    df.columns = [paper_id_col] + criteria

    # Enforce row count/order by position
    if df.shape[0] != len(paper_ids):
        raise ValueError(f"{path}: expected exactly {len(paper_ids)} rows (one per paper), got {df.shape[0]}.")

    # Set index to predefined order (position-based — we *overwrite* with PAPER_IDS)
    df[paper_id_col] = paper_ids
    df = df.set_index(paper_id_col)

    # Canonicalize labels
    for c in criteria:
        df[c] = df[c].apply(_canon_label)

    return df

def build_comparison(llm_df: pd.DataFrame, gt_df: pd.DataFrame, paper_ids: list[str], criteria: list[str], sep: str) -> pd.DataFrame:
    """Return a criteria × papers table with 'llm / ground truth' strings."""
    out = pd.DataFrame(index=criteria, columns=paper_ids, dtype=object)
    for p in paper_ids:
        for c in criteria:
            pred  = "" if pd.isna(llm_df.loc[p, c]) else str(llm_df.loc[p, c])
            truth = "" if pd.isna(gt_df.loc[p, c])  else str(gt_df.loc[p, c])
            out.at[c, p] = f"{pred}{sep}{truth}"
    return out

# %%
llm = load_by_position(df_llm ,LLM_CSV_PATH, PAPER_IDS, CRITERIA, PAPER_ID_COL)
gt  = load_by_position(df_gt, GT_CSV_PATH,  PAPER_IDS, CRITERIA, PAPER_ID_COL)

# =========================
# Build and display comparison
# =========================
comparison = build_comparison(llm, gt, PAPER_IDS, CRITERIA, DISPLAY_SEPARATOR)

# Add accuracy column per-criterion (row)
# Definition: fraction of papers where LLM == GT for that criterion.
# Denominator uses papers with non-empty ground-truth for that criterion.
acc_values = []
for crit in CRITERIA:
    preds = llm.loc[PAPER_IDS, crit]
    truths = gt.loc[PAPER_IDS, crit]
    mask = truths.astype(str).str.len() > 0  # count only where GT present
    total = int(mask.sum())
    matches = int((preds[mask] == truths[mask]).sum()) if total > 0 else 0
    acc_pct = (matches / total * 100.0) if total > 0 else None
    formatted = f"{matches}/{total} ({acc_pct:.1f}%)" if total > 0 else "n/a"
    acc_values.append(formatted)

comparison["accuracy"] = acc_values

print("=== Criteria x Papers (LLM / Ground Truth) with per-criterion accuracy ===")
display(comparison)

# save
# comparison.to_csv("rob_comparison_llm_vs_gt_based.csv", index=True)
# Out:
# === Criteria x Papers (LLM / Ground Truth) with per-criterion accuracy ===
#              Allcott, H (2011) (1) Ayres, Raseman, Shih, 2012  \
# criteria a.1             yes / yes                    no / no
# criteria a.2             yes / yes                  yes / yes
# criteria a.3              yes / no                   yes / no
# criteria a.4              no / yes                    no / no
# criteria a.5               no / no                   no / yes
# criteria b.1              no / yes                   yes / no
# criteria b.2             yes / yes                   yes / no
# criteria b.3              yes / no                   no / yes
# criteria b.4              no / yes                   no / yes
# criteria b.5              yes / no                  yes / yes
# criteria c                yes / no                   yes / no
# criteria d.1              yes / no                   yes / no
# criteria d.2               no / no                   no / yes
# criteria d.3              no / yes                  yes / yes
# criteria e.1              yes / no                  yes / yes
# criteria e.2               no / no                   yes / no
# criteria e.3               no / no                  yes / yes
# criteria e.4              no / yes                  yes / yes
#
#              Bager, S; Mundaca, L (2017)  \
# criteria a.1                    no / yes
# criteria a.2                   yes / yes
# criteria a.3                     no / no
# criteria a.4                   yes / yes
# criteria a.5                    yes / no
# criteria b.1                    yes / no
# criteria b.2                     no / no
# criteria b.3                    yes / no
# criteria b.4                    yes / no
# criteria b.5                     no / no
# criteria c                      yes / no
# criteria d.1                    yes / no
# criteria d.2                    no / yes
# criteria d.3                   yes / yes
# criteria e.1                     no / no
# criteria e.2                   yes / yes
# criteria e.3                     no / no
# criteria e.4                    yes / no
#
#              Carroll, J; Lyons, S; Denny, E (2014)  \
# criteria a.1                               no / no
# criteria a.2                             yes / yes
# criteria a.3                             yes / yes
# criteria a.4                              no / yes
# criteria a.5                              yes / no
# criteria b.1                             yes / yes
# criteria b.2                              no / yes
# criteria b.3                               no / no
# criteria b.4                               no / no
# criteria b.5                               no / no
# criteria c                                 no / no
# criteria d.1                              yes / no
# criteria d.2                               no / no
# criteria d.3                              yes / no
# criteria e.1                             yes / yes
# criteria e.2                               no / no
# criteria e.3                              yes / no
# criteria e.4                             yes / yes
#
#              Houde, S; Todd, A; Sudarshan, A; Flora, JA; Armel, KC (2013)  \
# criteria a.1                                            no / no
# criteria a.2                                          yes / yes
# criteria a.3                                          yes / yes
# criteria a.4                                           no / yes
# criteria a.5                                          yes / yes
# criteria b.1                                            no / no
# criteria b.2                                            no / no
# criteria b.3                                            no / no
# criteria b.4                                            no / no
# criteria b.5                                            no / no
# criteria c                                             yes / no
# criteria d.1                                            no / no
# criteria d.2                                           no / yes
# criteria d.3                                           yes / no
# criteria e.1                                            no / no
# criteria e.2                                           no / yes
# criteria e.3                                           yes / no
# criteria e.4                                           no / yes
#
#              Marangoni and Tavoni, 2021 Matsukawa, I. (2018)     accuracy
# criteria a.1                    no / no            yes / yes  6/7 (85.7%)
# criteria a.2                   no / yes             no / yes  5/7 (71.4%)
# criteria a.3                   yes / no              no / no  4/7 (57.1%)
# criteria a.4                   yes / no              no / no  3/7 (42.9%)
# criteria a.5                   yes / no            yes / yes  3/7 (42.9%)
# criteria b.1                    no / no             yes / no  3/7 (42.9%)
# criteria b.2                   no / yes             no / yes  3/7 (42.9%)
# criteria b.3                    no / no            yes / yes  4/7 (57.1%)
# criteria b.4                  yes / yes             yes / no  3/7 (42.9%)
# criteria b.5                   no / yes             no / yes  4/7 (57.1%)
# criteria c                     no / yes             no / yes  1/7 (14.3%)
# criteria d.1                   no / yes             yes / no  1/7 (14.3%)
# criteria d.2                  yes / yes             no / yes  3/7 (42.9%)
# criteria d.3                   yes / no             yes / no  2/7 (28.6%)
# criteria e.1                   yes / no            yes / yes  5/7 (71.4%)
# criteria e.2                  yes / yes              no / no  5/7 (71.4%)
# criteria e.3                  yes / yes             yes / no  4/7 (57.1%)
# criteria e.4                   yes / no            yes / yes  3/7 (42.9%)

# %% [markdown]
# # Individual Datasets

# %%
# =========================
# show formatted LLM and GT DataFrames
# =========================
print("=== LLM DataFrame (formatted) ===")
display(llm.applymap(_canon_label))
# Out:
# === LLM DataFrame (formatted) ===
#                                                    criteria a.1 criteria a.2  \
# paper_id
# Allcott, H (2011) (1)                                       yes          yes
# Ayres, Raseman, Shih, 2012                                   no          yes
# Bager, S; Mundaca, L (2017)                                  no          yes
# Carroll, J; Lyons, S; Denny, E (2014)                        no          yes
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...           no          yes
# Marangoni and Tavoni, 2021                                   no           no
# Matsukawa, I. (2018)                                        yes           no
#
#                                                    criteria a.3 criteria a.4  \
# paper_id
# Allcott, H (2011) (1)                                       yes           no
# Ayres, Raseman, Shih, 2012                                  yes           no
# Bager, S; Mundaca, L (2017)                                  no          yes
# Carroll, J; Lyons, S; Denny, E (2014)                       yes           no
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...          yes           no
# Marangoni and Tavoni, 2021                                  yes          yes
# Matsukawa, I. (2018)                                         no           no
#
#                                                    criteria a.5 criteria b.1  \
# paper_id
# Allcott, H (2011) (1)                                        no           no
# Ayres, Raseman, Shih, 2012                                   no          yes
# Bager, S; Mundaca, L (2017)                                 yes          yes
# Carroll, J; Lyons, S; Denny, E (2014)                       yes          yes
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...          yes           no
# Marangoni and Tavoni, 2021                                  yes           no
# Matsukawa, I. (2018)                                        yes          yes
#
#                                                    criteria b.2 criteria b.3  \
# paper_id
# Allcott, H (2011) (1)                                       yes          yes
# Ayres, Raseman, Shih, 2012                                  yes           no
# Bager, S; Mundaca, L (2017)                                  no          yes
# Carroll, J; Lyons, S; Denny, E (2014)                        no           no
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...           no           no
# Marangoni and Tavoni, 2021                                   no           no
# Matsukawa, I. (2018)                                         no          yes
#
#                                                    criteria b.4 criteria b.5  \
# paper_id
# Allcott, H (2011) (1)                                        no          yes
# Ayres, Raseman, Shih, 2012                                   no          yes
# Bager, S; Mundaca, L (2017)                                 yes           no
# Carroll, J; Lyons, S; Denny, E (2014)                        no           no
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...           no           no
# Marangoni and Tavoni, 2021                                  yes           no
# Matsukawa, I. (2018)                                        yes           no
#
#                                                    criteria c criteria d.1  \
# paper_id
# Allcott, H (2011) (1)                                     yes          yes
# Ayres, Raseman, Shih, 2012                                yes          yes
# Bager, S; Mundaca, L (2017)                               yes          yes
# Carroll, J; Lyons, S; Denny, E (2014)                      no          yes
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...        yes           no
# Marangoni and Tavoni, 2021                                 no           no
# Matsukawa, I. (2018)                                       no          yes
#
#                                                    criteria d.2 criteria d.3  \
# paper_id
# Allcott, H (2011) (1)                                        no           no
# Ayres, Raseman, Shih, 2012                                   no          yes
# Bager, S; Mundaca, L (2017)                                  no          yes
# Carroll, J; Lyons, S; Denny, E (2014)                        no          yes
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...           no          yes
# Marangoni and Tavoni, 2021                                  yes          yes
# Matsukawa, I. (2018)                                         no          yes
#
#                                                    criteria e.1 criteria e.2  \
# paper_id
# Allcott, H (2011) (1)                                       yes           no
# Ayres, Raseman, Shih, 2012                                  yes          yes
# Bager, S; Mundaca, L (2017)                                  no          yes
# Carroll, J; Lyons, S; Denny, E (2014)                       yes           no
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...           no           no
# Marangoni and Tavoni, 2021                                  yes          yes
# Matsukawa, I. (2018)                                        yes           no
#
#                                                    criteria e.3 criteria e.4
# paper_id
# Allcott, H (2011) (1)                                        no           no
# Ayres, Raseman, Shih, 2012                                  yes          yes
# Bager, S; Mundaca, L (2017)                                  no          yes
# Carroll, J; Lyons, S; Denny, E (2014)                       yes          yes
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...          yes           no
# Marangoni and Tavoni, 2021                                  yes          yes
# Matsukawa, I. (2018)                                        yes          yes

# %%
print("=== Ground Truth DataFrame (formatted) ===")
display(gt.applymap(_canon_label))
# Out:
# === Ground Truth DataFrame (formatted) ===
#                                                    criteria a.1 criteria a.2  \
# paper_id
# Allcott, H (2011) (1)                                       yes          yes
# Ayres, Raseman, Shih, 2012                                   no          yes
# Bager, S; Mundaca, L (2017)                                 yes          yes
# Carroll, J; Lyons, S; Denny, E (2014)                        no          yes
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...           no          yes
# Marangoni and Tavoni, 2021                                   no          yes
# Matsukawa, I. (2018)                                        yes          yes
#
#                                                    criteria a.3 criteria a.4  \
# paper_id
# Allcott, H (2011) (1)                                        no          yes
# Ayres, Raseman, Shih, 2012                                   no           no
# Bager, S; Mundaca, L (2017)                                  no          yes
# Carroll, J; Lyons, S; Denny, E (2014)                       yes          yes
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...          yes          yes
# Marangoni and Tavoni, 2021                                   no           no
# Matsukawa, I. (2018)                                         no           no
#
#                                                    criteria a.5 criteria b.1  \
# paper_id
# Allcott, H (2011) (1)                                        no          yes
# Ayres, Raseman, Shih, 2012                                  yes           no
# Bager, S; Mundaca, L (2017)                                  no           no
# Carroll, J; Lyons, S; Denny, E (2014)                        no          yes
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...          yes           no
# Marangoni and Tavoni, 2021                                   no           no
# Matsukawa, I. (2018)                                        yes           no
#
#                                                    criteria b.2 criteria b.3  \
# paper_id
# Allcott, H (2011) (1)                                       yes           no
# Ayres, Raseman, Shih, 2012                                   no          yes
# Bager, S; Mundaca, L (2017)                                  no           no
# Carroll, J; Lyons, S; Denny, E (2014)                       yes           no
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...           no           no
# Marangoni and Tavoni, 2021                                  yes           no
# Matsukawa, I. (2018)                                        yes          yes
#
#                                                    criteria b.4 criteria b.5  \
# paper_id
# Allcott, H (2011) (1)                                       yes           no
# Ayres, Raseman, Shih, 2012                                  yes          yes
# Bager, S; Mundaca, L (2017)                                  no           no
# Carroll, J; Lyons, S; Denny, E (2014)                        no           no
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...           no           no
# Marangoni and Tavoni, 2021                                  yes          yes
# Matsukawa, I. (2018)                                         no          yes
#
#                                                    criteria c criteria d.1  \
# paper_id
# Allcott, H (2011) (1)                                      no           no
# Ayres, Raseman, Shih, 2012                                 no           no
# Bager, S; Mundaca, L (2017)                                no           no
# Carroll, J; Lyons, S; Denny, E (2014)                      no           no
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...         no           no
# Marangoni and Tavoni, 2021                                yes          yes
# Matsukawa, I. (2018)                                      yes           no
#
#                                                    criteria d.2 criteria d.3  \
# paper_id
# Allcott, H (2011) (1)                                        no          yes
# Ayres, Raseman, Shih, 2012                                  yes          yes
# Bager, S; Mundaca, L (2017)                                 yes          yes
# Carroll, J; Lyons, S; Denny, E (2014)                        no           no
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...          yes           no
# Marangoni and Tavoni, 2021                                  yes           no
# Matsukawa, I. (2018)                                        yes           no
#
#                                                    criteria e.1 criteria e.2  \
# paper_id
# Allcott, H (2011) (1)                                        no           no
# Ayres, Raseman, Shih, 2012                                  yes           no
# Bager, S; Mundaca, L (2017)                                  no          yes
# Carroll, J; Lyons, S; Denny, E (2014)                       yes           no
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...           no          yes
# Marangoni and Tavoni, 2021                                   no          yes
# Matsukawa, I. (2018)                                        yes           no
#
#                                                    criteria e.3 criteria e.4
# paper_id
# Allcott, H (2011) (1)                                        no          yes
# Ayres, Raseman, Shih, 2012                                  yes          yes
# Bager, S; Mundaca, L (2017)                                  no           no
# Carroll, J; Lyons, S; Denny, E (2014)                        no          yes
# Houde, S; Todd, A; Sudarshan, A; Flora, JA; Arm...           no          yes
# Marangoni and Tavoni, 2021                                  yes           no
# Matsukawa, I. (2018)                                         no          yes

# %%
# =========================
# show raw LLM and GT DataFrames
# =========================
print("=== LLM DataFrame (raw) ===")
df_llm
# Out:
# === LLM DataFrame (raw) ===
#                                             paper_id  criteria a.1  \
# 0                              Allcott, H (2011) (1)           yes
# 1                         Ayres, Raseman, Shih, 2012   probably no
# 2                        Bager, S; Mundaca, L (2017)   probably no
# 3              Carroll, J; Lyons, S; Denny, E (2014)            no
# 4  Houde, S; Todd, A; Sudarshan, A; Flora, JA; Ar...   probably no
# 5                         Marangoni and Tavoni, 2021            no
# 6                               Matsukawa, I. (2018)  probably yes
#
#    criteria a.2  criteria a.3 criteria a.4  criteria a.5  criteria b.1  \
# 0           yes  probably yes           no            no            no
# 1  probably yes           yes           no   probably no  probably yes
# 2           yes   probably no          yes  probably yes  probably yes
# 3  probably yes  probably yes           no  probably yes           yes
# 4  probably yes           yes           no  probably yes            no
# 5   probably no           yes          yes           yes            no
# 6   probably no            no  probably no           yes  probably yes
#
#    criteria b.2 criteria b.3  criteria b.4  criteria b.5    criteria c  \
# 0           yes          yes   probably no           yes           yes
# 1  probably yes           no            no  probably yes           yes
# 2            no          yes           yes            no  probably yes
# 3            no           no            no   probably no   probably no
# 4   probably no  probably no   probably no            no  probably yes
# 5            no  probably no           yes   probably no   probably no
# 6            no          yes  probably yes            no            no
#
#    criteria d.1  criteria d.2  criteria d.3  criteria e.1  criteria e.2  \
# 0           yes            no            no           yes            no
# 1           yes   probably no           yes  probably yes  probably yes
# 2           yes            no           yes   probably no  probably yes
# 3  probably yes            no  probably yes           yes            no
# 4            no            no  probably yes   probably no   probably no
# 5   probably no  probably yes           yes           yes  probably yes
# 6  probably yes            no           yes  probably yes   probably no
#
#    criteria e.3  criteria e.4
# 0   probably no            no
# 1  probably yes           yes
# 2   probably no  probably yes
# 3           yes  probably yes
# 4  probably yes            no
# 5  probably yes           yes
# 6           yes           yes

# %%
print("=== Ground Truth DataFrame (raw) ===")
df_gt
# Out:
# === Ground Truth DataFrame (raw) ===
#                                             paper_id  criteria a.1  \
# 0                              Allcott, H (2011) (1)  probably yes
# 1                         Ayres, Raseman, Shih, 2012   probably no
# 2                        Bager, S; Mundaca, L (2017)  probably yes
# 3              Carroll, J; Lyons, S; Denny, E (2014)   probably no
# 4  Houde, S; Todd, A; Sudarshan, A; Flora, JA; Ar...   probably no
# 5                         Marangoni and Tavoni, 2021   probably no
# 6                               Matsukawa, I. (2018)           yes
#
#    criteria a.2 criteria a.3  criteria a.4 criteria a.5  criteria b.1  \
# 0  probably yes           no           yes           no           yes
# 1  probably yes  probably no   probably no          yes            no
# 2           yes           no  probably yes  probably no            no
# 3           yes          yes           yes  probably no  probably yes
# 4           yes          yes           yes          yes            no
# 5  probably yes  probably no   probably no           no            no
# 6           yes           no   probably no          yes            no
#
#    criteria b.2 criteria b.3  criteria b.4  criteria b.5    criteria c  \
# 0           yes  probably no           yes            no            no
# 1            no          yes  probably yes           yes            no
# 2            no  probably no            no   probably no   probably no
# 3           yes           no            no            no   probably no
# 4            no  probably no   probably no   probably no            no
# 5  probably yes           no           yes           yes  probably yes
# 6           yes          yes   probably no  probably yes  probably yes
#
#   criteria d.1  criteria d.2  criteria d.3  criteria e.1  criteria e.2  \
# 0  probably no            no  probably yes   probably no            no
# 1           no           yes           yes           yes            no
# 2           no           yes           yes   probably no  probably yes
# 3           no   probably no            no  probably yes   probably no
# 4  probably no           yes            no   probably no           yes
# 5          yes           yes   probably no            no           yes
# 6           no  probably yes            no  probably yes   probably no
#
#   criteria e.3  criteria e.4
# 0           no  probably yes
# 1          yes           yes
# 2  probably no   probably no
# 3           no           yes
# 4  probably no  probably yes
# 5          yes            no
# 6           no  probably yes

# %% [markdown]
# # Risk Level Comparison (coming soon)
